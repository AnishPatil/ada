# %%
import subprocess
import warnings
import tempfile
import numpy as np
import pandas as pd
from ada.geometry.airfoils.kulfan import Kulfan
import os
import math
import shutil
path_to_XFOIL = shutil.which('xfoil')
import pathlib
# path_to_here = pathlib.Path(__file__).parent.resolve()

def run(mode, 
        upperKulfanCoefficients,
        lowerKulfanCoefficients,
        val = 0.0, 
        Re = 1e7,
        M = 0.0,
        xtp_u=1.0,
        xtp_l=1.0,
        N_crit=9.0,
        N_panels = 160,
        flapLocation = None,
        flapDeflection = 0.0,
        polarfile      = None,
        cpDatafile     = None,
        blDatafile     = None,
        defaultDatfile = None,
        executionFile  = None,
        stdoutFile     = None,
        TE_gap = 0.0,
        timelimit = 10,
        max_iter=200):

    try:
        iter(val)
        is_iterable = True
    except TypeError:
        is_iterable = False

    # if 'dcmania' in str(path_to_here):
    #     tfpre = '/gpfs/dcmania/tempfiles/tmp_'
    # elif 'ahsieh' in str(path_to_here):
    #     tfpre = '/gpfs/ahsieh/tempfiles/tmp_'
    # elif 'karch' in str(path_to_here):
    tfpre = '.'
    # else:
    #     # Default to David's file system
    #     tfpre = '/gpfs/dcmania/tempfiles/tmp_'

    tempDatfile    = tempfile.NamedTemporaryFile(mode = 'w', prefix=tfpre, delete=False)
    tempPolarfile  = tempfile.NamedTemporaryFile(mode = 'w', prefix=tfpre, delete=True )
    # tempCpDatafile = tempfile.NamedTemporaryFile(mode = 'w', prefix=tfpre, delete=True )
    # tempBlDatafile = tempfile.NamedTemporaryFile(mode = 'w', prefix=tfpre, delete=True )
    # tempStdoutFile = tempfile.NamedTemporaryFile(mode = 'w', prefix=tfpre, delete=False)
    # tempStdoutFile = tempfile.NamedTemporaryFile(mode = 'w', prefix=tfpre, delete=True)
    tempExecFile   = tempfile.NamedTemporaryFile(mode = 'w', prefix=tfpre, delete=False)
    
    # need names, but not files
    # xfoil will require additional instructions if these files exist
    tempPolarfile.close()
    # tempCpDatafile.close()
    # tempBlDatafile.close()
    # tempStdoutFile.close()

    numberOfPanels = N_panels

    mode = mode.lower()
    if mode == 'alpha':
        mode = 'alfa'

    if mode not in ['alfa','cl']:
        raise ValueError('Invalid input mode.  Must be one of: alfa, cl ')

    # Removed this to keep to only standard type inputs
    # if isinstance(airfoil, str):        
    #     if ('.dat' in airfoil) or ('.txt' in airfoil):
    #         if os.path.isfile(airfoil):
    #             topline = 'load ' + airfoil + ' \n afl \n'
    #         else:
    #             raise ValueError('Could not find airfoil to be read')
    #     ck1 = 'naca' == airfoil.lower()[0:4]
    #     ck2 = airfoil[-4:].isdigit()
    #     if ck1:
    #         if ck2 and (len(airfoil)!=8):
    #             afl = airfoil.split()
    #             airfoil = afl[0]+afl[1]
    #         if ck2 and (len(airfoil)==8):
    #             topline = airfoil + ' \n'
    #         else:
    #             raise ValueError('Could not parse the NACA 4 digit airfoil')
        
    # elif isinstance(airfoil, Kulfan):
    #     if os.path.isfile(defaultDatfile):
    #         os.remove(defaultDatfile)
    #     airfoil.write2file(defaultDatfile)
    #     topline = 'load ' + defaultDatfile + ' \n' + 'airfoil \n'
        
    # else:
    #     raise ValueError('Could not parse airfoil')

    airfoil = Kulfan(TE_gap=TE_gap)
    airfoil.upperCoefficients = upperKulfanCoefficients
    airfoil.lowerCoefficients = lowerKulfanCoefficients
    airfoil.write2file(tempDatfile)
    # print(airfoil.tau)
    
    # if not closed, xfoil flags as invalid file tye
    tempDatfile.close()
    
    topline = 'load ' + tempDatfile.name + ' \n' + 'airfoil \n'
    
    # proc = subprocess.Popen([path_to_XFOIL], stdout=subprocess.PIPE, stdin=subprocess.PIPE)
    estr = ''
    estr += 'plop\n'
    estr += 'g\n'
    estr += '\n'
    estr += topline
    estr += 'ppar\n'
    estr += 'n %d\n'%(numberOfPanels)
    estr += '\n'
    estr += '\n'
    if flapLocation is not None:
        ck1 = flapLocation >= 0.0
        ck2 = flapLocation <= 1.0
        if ck1 and ck2:
            estr += 'gdes \n'
            estr += 'flap \n'
            estr += '%f \n'%(flapLocation)
            estr += '999 \n'
            estr += '0.5 \n'
            estr += '%f \n'%(flapDeflection)
            estr += 'x \n'
            estr += '\n'
        else:
            raise ValueError('Invalid flapLocation.  Must be between 0.0 and 1.0')
    estr += 'oper \n'
    estr += "iter %d\n" %(max_iter)
    #run inviscid first
    if is_iterable:
        if mode == 'alfa':
            estr += "alfa %.2f \n" %(val[0])
        if mode == 'cl':
            estr += "cl %.3f \n" %(val[0])        
    else:
        if mode == 'alfa':
            estr += "alfa %.2f \n" %(val)
        if mode == 'cl':
            estr += "cl %.3f \n" %(val)
    estr += 'visc \n'
    estr += "%.0f \n" %(float(Re))
    estr += "M \n"
    estr += "%.2f \n" %(M)
    estr += 'vpar \n'
    estr += 'xtr \n'
    estr += '%f \n'%(xtp_u)
    estr += '%f \n'%(xtp_l)
    estr += 'n \n'
    estr += '%f \n'%(N_crit)
    estr += '\n'
    estr += 'pacc \n'
    estr += '\n'
    estr += '\n'

    if is_iterable:
        if mode == 'alfa':
            estr += "aseq %.2f %.2f %.2f \n" %(val[0],val[1],val[2])
        if mode == 'cl':
            estr += "cseq %.3f %.3f %.3f \n" %(val[0],val[1],val[2])    

        estr += 'pwrt \n'
        estr += tempPolarfile.name + ' \n'    
        estr += '\n'
        estr += 'q \n'

    else:
        if mode == 'alfa':
            estr += "alfa %.2f \n" %(val)
        if mode == 'cl':
            estr += "cl %.3f \n" %(val)
        estr += 'pwrt \n'
        estr += tempPolarfile.name + ' \n'
        # estr += 'cpwr \n'
        # estr += tempCpDatafile.name + '\n'
        # estr += 'dump \n'
        # estr += tempBlDatafile.name + '\n'
        estr += '\n'
        estr += 'q \n'

    tempExecFile.write(estr)
    tempExecFile.close()

    if executionFile is not None:
        exFile = open(executionFile,'w')
        exFile.write(estr)
        exFile.close()
    
    # proc = subprocess.Popen([path_to_XFOIL], stdout=subprocess.PIPE, stdin=subprocess.PIPE)
    # proc.stdin.write(estr.encode())

    # try:
    #     stdout_val = proc.communicate(timeout=5)[0]
    #     tempStdoutFile.write(stdout_val.decode())
    # except TimeoutExpired:
    #     # process timed out but kept running, will be handled below as a normal failure
    #     proc.kill()
    # except:
    #     # process failed, will be handled below as a normal failure
    #     pass
    # proc.stdin.close()

    cmd = ''
    # cmd += 'timelimit -t2 '
    # cmd += 'timeout 2 '
    # if 'dcmania' in str(path_to_here):
    #     cmd += 'timeout %d '%(timelimit)
    # elif 'ahsieh' in str(path_to_here):
    #     cmd += 'timeout %d '%(timelimit)
    # elif 'karch' in str(path_to_here):
    cmd += 'timelimit -t%d '%(timelimit)
    # else:
    #     # Default to linux
    #     cmd += 'timeout %d '%(timelimit)

    cmd += path_to_XFOIL
    cmd += ' <' + tempExecFile.name
    # cmd += ' >'+tempStdoutFile.name
    # print(estr)

    try:
        # stdout_val = subprocess.check_output(cmd, shell=True, timeout=5)
        subprocess.run(cmd, shell=True)
    except:
        # process failed or timed out, will be handled below as a normal failure
        # print( upperKulfanCoefficients, lowerKulfanCoefficients, val)
        pass
    
    # try:
    with warnings.catch_warnings():
        # catch warning for empty file
        warnings.simplefilter('ignore')
        data = np.genfromtxt(tempPolarfile.name, skip_header=12)

    if not is_iterable:
        alpha   = data[0]
        cl      = data[1]
        cd      = data[2]
        cdp     = data[3]
        cm      = data[4]
        xtr_top = data[5]
        xtr_bot = data[6]
        Reval   = Re
        Mval    = M

    else:
        alpha   = data[:,0]
        cl      = data[:,1]
        cd      = data[:,2]
        cdp     = data[:,3]
        cm      = data[:,4]
        xtr_top = data[:,5]
        xtr_bot = data[:,6]
        Reval   = Re
        Mval    = M

    # cpData = pd.read_csv(tempCpDatafile.name, sep="\s+",skiprows=1, names = ['x' , 'cp'])

    # blData = pd.read_csv(tempBlDatafile.name, sep="\s+",skiprows=1, names = ['s', 'x', 'y', 'Ue/Vinf', 'Dstar', 'Theta', 'Cf', 'H', 'H*', 'P', 'm', 'K', 'tau', 'Di'])

    res = {}
    res['cd'] = cd
    res['cl'] = cl
    res['alpha'] = alpha
    res['cm'] = cm
    res['xtr_top'] = xtr_top
    res['xtr_bot'] = xtr_bot
    res['Re'] = Reval
    res['M'] = Mval
    res['N_crit'] = N_crit
    res['N_panels'] = N_panels
    # res['cp_data'] = cpData.to_dict('list')
    # res['bl_data'] = blData.to_dict('list')
    # res['stdout'] = stdout_val.decode()

    # std_f = open(tempStdoutFile.name,'r')
    # std_vl = std_f.read()
    # std_f.close()
    # res['stdout'] = std_vl

    # except:
    #     res = None

    if polarfile is not None:
        shutil.copy( tempPolarfile.name , polarfile)
    # if cpDatafile is not None:
    #     shutil.copy( tempCpDatafile.name , cpDatafile)
    # if blDatafile is not None:
    #     shutil.copy( tempBlDatafile.name , blDatafile)
    if defaultDatfile is not None:
        shutil.copy( tempDatfile.name , defaultDatfile)
    # if stdoutFile is not None:
    #     shutil.copy( tempStdoutFile.name , stdoutFile)

    if tempDatfile is not None:
        tempDatfile.close()
    # tempStdoutFile.close()
    # tempExecFile.close()


    if os.path.exists(tempDatfile.name):
        os.remove(tempDatfile.name)
    if os.path.exists(tempPolarfile.name):
        os.remove(tempPolarfile.name)
    # if os.path.exists(tempCpDatafile.name):
    #     os.remove(tempCpDatafile.name)
    # if os.path.exists(tempBlDatafile.name):
    #     os.remove(tempBlDatafile.name)
    # if os.path.exists(tempStdoutFile.name):
    #     os.remove(tempStdoutFile.name)
    if os.path.exists(tempExecFile.name):
        os.remove(tempExecFile.name)


    # os.remove(tempDatfile.name)
    # # os.remove(tempPolarfile.name)
    # # os.remove(tempCpDatafile.name)
    # # os.remove(tempBlDatafile.name)
    # # os.remove(tempStdoutFile.name)
    # os.remove(tempExecFile.name)

    return res


res1 = run('alfa', [.2,.3,.1],[-.1,-.1,-.1], [0, 30,0.25], Re=1e6, N_crit=9.0, xtp_u=1.0, xtp_l=1.0, timelimit=10)
res2 = run('alfa', [.2,.3,.1],[-.1,-.1,-.1], [0,-30,0.25], Re=1e6, N_crit=9.0, xtp_u=1.0, xtp_l=1.0, timelimit=10)
alpha = np.array(list(reversed(res2['alpha'].tolist()))[0:-1] + res1['alpha'].tolist() )
cd = np.array(list(reversed(res2['cd'].tolist()))[0:-1] + res1['cd'].tolist() )
cl = np.array(list(reversed(res2['cl'].tolist()))[0:-1] + res1['cl'].tolist() )
plt.plot(cl,cl/cd)
# Out:
#  ===================================================
#   XFOIL Version 6.99
#   Copyright (C) 2000   Mark Drela, Harold Youngren
#
#   This software comes with ABSOLUTELY NO WARRANTY,
#     subject to the GNU General Public License.
#
#   Caveat computor
#  ===================================================
#
#  File  xfoil.def  not found
#
#    QUIT    Exit program
#
#   .OPER    Direct operating point(s)
#   .MDES    Complex mapping design routine
#   .QDES    Surface speed design routine
#   .GDES    Geometry design routine
#
#    SAVE f  Write airfoil to labeled coordinate file
#    PSAV f  Write airfoil to plain coordinate file
#    ISAV f  Write airfoil to ISES coordinate file
#    MSAV f  Write airfoil to MSES coordinate file
#    REVE    Reverse written-airfoil node ordering
#    DELI i  Change written-airfoil file delimiters
#
#    LOAD f  Read buffer airfoil from coordinate file
#    NACA i  Set NACA 4,5-digit airfoil and buffer airfoil
#    INTE    Set buffer airfoil by interpolating two airfoils
#    NORM    Buffer airfoil normalization toggle
#    HALF    Halve the number of points in buffer airfoil
#    XYCM rr Change CM reference location, currently  0.25000 0.00000
#
#    BEND    Display structural properties of current airfoil
#
#    PCOP    Set current-airfoil panel nodes directly from buffer airfoil points
#    PANE    Set current-airfoil panel nodes ( 160 ) based on curvature
#   .PPAR    Show/change paneling
#
#   .PLOP    Plotting options
#
#    WDEF f  Write  current-settings file
#    RDEF f  Reread current-settings file
#    NAME s  Specify new airfoil name
#    NINC    Increment name version number
#
#    Z       Zoom    | (available in all menus)
#    U       Unzoom  |
#
#  XFOIL   c>   ...............................................
#
#   G raphics-enable flag:        T
#   S ize of plot object          10.00"
#   A spect ratio of plot object   0.5500
#   P age dimensions              11.00 x  8.50"
#   M argins from page edges       0.00",  0.00"
#   F ont size (relative)          0.0150
#   W indow/screen size fraction   0.8000
#   B lowup input method:        Cursor
#   O rientation of plot:        Landscape
#   C olor PostScript output?     T
#   L ine colors for top,bottom    8  3
#
#       Option, Value   (or <Return>)    c>   ...............................................
#
#   G raphics-enable flag:        F
#   S ize of plot object          10.00"
#   A spect ratio of plot object   0.5500
#   P age dimensions              11.00 x  8.50"
#   M argins from page edges       0.00",  0.00"
#   F ont size (relative)          0.0150
#   W indow/screen size fraction   0.8000
#   B lowup input method:        Cursor
#   O rientation of plot:        Landscape
#   C olor PostScript output?     T
#   L ine colors for top,bottom    8  3
#
#       Option, Value   (or <Return>)    c>
#  XFOIL   c>
#  Plain airfoil file
#
# Enter airfoil name   s>
#  Number of input coordinate points: 199
#  Counterclockwise ordering
#  Max thickness =     0.128300  at x =   0.333
#  Max camber    =     0.025426  at x =   0.333
#
#   LE  x,y  =  -0.00001   0.00035  |   Chord =   1.00001
#   TE  x,y  =   1.00000   0.00000  |
#
#  Current airfoil nodes set from buffer airfoil nodes ( 199 )
#
#  XFOIL   c>
#     Present paneling parameters...
#   N  i   Number of panel nodes       160
#   P  r   Panel bunching parameter    1.000
#   T  r   TE/LE panel density ratio   0.150
#   R  r   Refined area/LE  panel density ratio   0.200
#   XT rr  Top    side refined area x/c limits    1.000 1.000
#   XB rr  Bottom side refined area x/c limits    1.000 1.000
#   Z oom
#   U nzoom
#   H ardcopy
#
# Change what ? (<cr> if nothing else)   c>
# Change what ? (<cr> if nothing else)   c>
#  Sharp trailing edge
#
#  Maximum panel corner angle = 17.140   at  i,x,y  =  84   0.0003  -0.0017
#
#     Present paneling parameters...
#   N  i   Number of panel nodes       160
#   P  r   Panel bunching parameter    1.000
#   T  r   TE/LE panel density ratio   0.150
#   R  r   Refined area/LE  panel density ratio   0.200
#   XT rr  Top    side refined area x/c limits    1.000 1.000
#   XB rr  Bottom side refined area x/c limits    1.000 1.000
#   Z oom
#   U nzoom
#   H ardcopy
#
# Change what ? (<cr> if nothing else)   c>
#  XFOIL   c>
# .OPERi   c>
# .OPERi   c>   Calculating unit vorticity distributions ...
#
# .OPERi   c>
# Enter Reynolds number   r>
#  M  =    0.0000
#  Re =  0.1000E+07
#
# .OPERv   c>
#  Currently...
#
#  M  =    0.0000
#
# Enter Mach number   r>
# .OPERv   c>
#  Xtr/c     =  1.0000    top    side
#  Xtr/c     =  1.0000    bottom side
#  NcritT    =    9.00   ( 0.070 % turb. level )
#  NcritB    =    9.00   ( 0.070 % turb. level )
#  Vacc      =  0.0100
#  WakeL/c   =   1.000
#
#  Klag  =  5.6000     Uxwt  =    1.00       Kdl =  0.9000
#  A     =  6.7000     B     =  0.7500       KCt = 0.01485
#  CtiniK=  1.8000     CtiniX=  3.3000
#
# ..VPAR   c>
# Enter top    side Xtrip/c   r>
# Enter bottom side Xtrip/c   r>
# ..VPAR   c>
# Enter critical amplification ratio   r>
# ..VPAR   c>
# .OPERv   c>
#  Polar  1 newly created for accumulation
#  Airfoil archived with polar: airfoil
#
# Enter  polar save filename  OR  <return> for no file   s>
#  Polar save file will NOT be written
#
# Enter  polar dump filename  OR  <return> for no file   s>
#  Polar dump file will NOT be written
#
#  Polar accumulation enabled
#
# .OPERva   c>   Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Initializing BL ...
#     side            1  ...
#  MRCHUE: Inverse mode at  46     Hk =   4.437
#  MRCHUE: Inverse mode at  47     Hk =   5.455
#  MRCHUE: Inverse mode at  48     Hk =   6.455
#  MRCHUE: Inverse mode at  49     Hk =   7.446
#  MRCHUE: Inverse mode at  50     Hk =   7.828
#  MRCHUE: Inverse mode at  51     Hk =   3.304
#     side            2  ...
#  MRCHUE: Inverse mode at  65     Hk =   4.181
#  MRCHUE: Inverse mode at  66     Hk =   4.885
#  MRCHUE: Inverse mode at  67     Hk =   5.581
#  MRCHUE: Inverse mode at  68     Hk =   2.789
#
#  Side 1  free  transition at x/c =  0.5363   50
#  Side 2  free  transition at x/c =  0.7978   68
#
#    1   rms: 0.1163E+00   max: -.8552E+00   C at   68  2   RLX: 0.585
#        a =  0.000      CL =  0.1738
#       Cm = -0.0178     CD =  0.00597   =>   CDf =  0.00482    CDp =  0.00114
#
#  Side 1  free  transition at x/c =  0.5533   52
#  Side 2  free  transition at x/c =  0.8214   69
#
#    2   rms: 0.9791E-01   max: -.1364E+01   C at   69  2   RLX: 0.367
#        a =  0.000      CL =  0.1711
#       Cm = -0.0172     CD =  0.00540   =>   CDf =  0.00441    CDp =  0.00098
#
#  Side 1  free  transition at x/c =  0.5649   52
#  Side 2  free  transition at x/c =  0.8268   70
#
#    3   rms: 0.5504E-01   max: -.6722E+00   C at   70  2   RLX: 0.744
#        a =  0.000      CL =  0.1651
#       Cm = -0.0159     CD =  0.00538   =>   CDf =  0.00437    CDp =  0.00101
#
#  Side 1  free  transition at x/c =  0.5786   53
#  Side 2  free  transition at x/c =  0.8554   71
#
#    4   rms: 0.1104E-01   max: 0.1952E+00   D at   53  1
#        a =  0.000      CL =  0.1598
#       Cm = -0.0145     CD =  0.00535   =>   CDf =  0.00404    CDp =  0.00131
#
#  Side 1  free  transition at x/c =  0.5805   53
#  Side 2  free  transition at x/c =  0.8580   71
#
#    5   rms: 0.4226E-02   max: -.8290E-01   C at   71  2
#        a =  0.000      CL =  0.1597
#       Cm = -0.0145     CD =  0.00537   =>   CDf =  0.00407    CDp =  0.00130
#
#  Side 1  free  transition at x/c =  0.5806   53
#  Side 2  free  transition at x/c =  0.8585   72
#
#    6   rms: 0.3035E-02   max: -.5252E-01   C at   72  2
#        a =  0.000      CL =  0.1597
#       Cm = -0.0145     CD =  0.00536   =>   CDf =  0.00406    CDp =  0.00130
#
#  Side 1  free  transition at x/c =  0.5806   53
#  Side 2  free  transition at x/c =  0.8590   72
#
#    7   rms: 0.1256E-03   max: 0.2083E-02   C at   72  2
#        a =  0.000      CL =  0.1597
#       Cm = -0.0145     CD =  0.00536   =>   CDf =  0.00405    CDp =  0.00131
#
#  Side 1  free  transition at x/c =  0.5806   53
#  Side 2  free  transition at x/c =  0.8590   72
#
#    8   rms: 0.2204E-06   max: -.2695E-05   D at   73  2
#        a =  0.000      CL =  0.1597
#       Cm = -0.0145     CD =  0.00536   =>   CDf =  0.00405    CDp =  0.00131
#       9.000    4.3356   0.005364   0.001372   0.001467   0.000096    0.5806     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5806   53
#  Side 2  free  transition at x/c =  0.8590   72
#
#    1   rms: 0.5178E-01   max: -.5218E+00   C at   72  2   RLX: 0.958
#        a =  0.250      CL =  0.1859
#       Cm = -0.0142     CD =  0.00529   =>   CDf =  0.00405    CDp =  0.00124
#
#  Side 1  free  transition at x/c =  0.5739   53
#  Side 2  free  transition at x/c =  0.8717   72
#
#    2   rms: 0.1362E-01   max: -.2080E+00   C at   72  2
#        a =  0.250      CL =  0.1866
#       Cm = -0.0142     CD =  0.00536   =>   CDf =  0.00410    CDp =  0.00127
#
#  Side 1  free  transition at x/c =  0.5744   53
#  Side 2  free  transition at x/c =  0.8862   73
#
#    3   rms: 0.8451E-02   max: -.1402E+00   C at   73  2
#        a =  0.250      CL =  0.1873
#       Cm = -0.0143     CD =  0.00534   =>   CDf =  0.00401    CDp =  0.00133
#
#  Side 1  free  transition at x/c =  0.5743   53
#  Side 2  free  transition at x/c =  0.8800   73
#
#    4   rms: 0.2471E-02   max: -.4331E-01   C at   73  2
#        a =  0.250      CL =  0.1870
#       Cm = -0.0142     CD =  0.00535   =>   CDf =  0.00401    CDp =  0.00133
#
#  Side 1  free  transition at x/c =  0.5743   53
#  Side 2  free  transition at x/c =  0.8813   73
#
#    5   rms: 0.2975E-04   max: -.5831E-03   D at   75  2
#        a =  0.250      CL =  0.1870
#       Cm = -0.0142     CD =  0.00535   =>   CDf =  0.00401    CDp =  0.00134
#       9.000    4.3272   0.005346   0.001383   0.001478   0.000096    0.5743     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5743   53
#  Side 2  free  transition at x/c =  0.8813   73
#
#    1   rms: 0.4656E-01   max: -.3708E+00   C at   73  2
#        a =  0.500      CL =  0.2144
#       Cm = -0.0139     CD =  0.00535   =>   CDf =  0.00400    CDp =  0.00135
#
#  Side 1  free  transition at x/c =  0.5681   54
#  Side 2  free  transition at x/c =  0.8957   73
#
#    2   rms: 0.7790E-02   max: -.1394E+00   C at   73  2
#        a =  0.500      CL =  0.2145
#       Cm = -0.0140     CD =  0.00538   =>   CDf =  0.00404    CDp =  0.00134
#
#  Side 1  free  transition at x/c =  0.5682   54
#  Side 2  free  transition at x/c =  0.9001   73
#
#    3   rms: 0.5589E-03   max: -.8880E-02   C at   73  2
#        a =  0.500      CL =  0.2145
#       Cm = -0.0140     CD =  0.00538   =>   CDf =  0.00402    CDp =  0.00137
#
#  Side 1  free  transition at x/c =  0.5682   54
#  Side 2  free  transition at x/c =  0.9002   73
#
#    4   rms: 0.2218E-05   max: 0.3966E-04   C at   73  2
#        a =  0.500      CL =  0.2145
#       Cm = -0.0140     CD =  0.00538   =>   CDf =  0.00402    CDp =  0.00137
#       9.000    4.2938   0.005384   0.001395   0.001476   0.000081    0.5682     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5682   54
#  Side 2  free  transition at x/c =  0.9002   73
#
#    1   rms: 0.4421E-01   max: -.2230E+00   C at   73  2
#        a =  0.750      CL =  0.2414
#       Cm = -0.0137     CD =  0.00546   =>   CDf =  0.00402    CDp =  0.00144
#
#  Side 1  free  transition at x/c =  0.5621   53
#  Side 2  free  transition at x/c =  0.9147   74
#
#    2   rms: 0.7790E-02   max: -.8617E-01   D at   53  1
#        a =  0.750      CL =  0.2432
#       Cm = -0.0140     CD =  0.00539   =>   CDf =  0.00401    CDp =  0.00139
#
#  Side 1  free  transition at x/c =  0.5624   53
#  Side 2  free  transition at x/c =  0.9158   74
#
#    3   rms: 0.4244E-03   max: 0.6386E-02   C at   53  1
#        a =  0.750      CL =  0.2432
#       Cm = -0.0140     CD =  0.00540   =>   CDf =  0.00399    CDp =  0.00140
#
#  Side 1  free  transition at x/c =  0.5622   53
#  Side 2  free  transition at x/c =  0.9159   74
#
#    4   rms: 0.1762E-05   max: -.1489E-04   D at   54  1
#        a =  0.750      CL =  0.2432
#       Cm = -0.0140     CD =  0.00540   =>   CDf =  0.00399    CDp =  0.00140
#       9.000    4.3100   0.005397   0.001406   0.001501   0.000095    0.5622     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5622   53
#  Side 2  free  transition at x/c =  0.9159   74
#
#    1   rms: 0.4257E-01   max: -.1494E+00   C at   74  2
#        a =  1.000      CL =  0.2710
#       Cm = -0.0138     CD =  0.00543   =>   CDf =  0.00399    CDp =  0.00143
#
#  Side 1  free  transition at x/c =  0.5552   53
#  Side 2  free  transition at x/c =  0.9284   75
#
#    2   rms: 0.2862E-02   max: -.2500E-01   C at   53  1
#        a =  1.000      CL =  0.2724
#       Cm = -0.0142     CD =  0.00545   =>   CDf =  0.00402    CDp =  0.00143
#
#  Side 1  free  transition at x/c =  0.5558   53
#  Side 2  free  transition at x/c =  0.9289   75
#
#    3   rms: 0.6854E-04   max: -.8051E-03   C at   75  2
#        a =  1.000      CL =  0.2724
#       Cm = -0.0142     CD =  0.00545   =>   CDf =  0.00401    CDp =  0.00144
#       9.000    4.2715   0.005453   0.001420   0.001503   0.000084    0.5558     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5558   53
#  Side 2  free  transition at x/c =  0.9289   75
#
#    1   rms: 0.4464E-01   max: 0.1497E+00   D at   76  2
#        a =  1.250      CL =  0.3016
#       Cm = -0.0143     CD =  0.00553   =>   CDf =  0.00400    CDp =  0.00153
#
#  Side 1  free  transition at x/c =  0.5500   53
#  Side 2  free  transition at x/c =  0.9380   75
#
#    2   rms: 0.9772E-02   max: -.1015E+00   C at   75  2
#        a =  1.250      CL =  0.3012
#       Cm = -0.0142     CD =  0.00551   =>   CDf =  0.00404    CDp =  0.00147
#
#  Side 1  free  transition at x/c =  0.5498   53
#  Side 2  free  transition at x/c =  0.9405   75
#
#    3   rms: 0.1266E-02   max: -.1362E-01   D at   79  2
#        a =  1.250      CL =  0.3019
#       Cm = -0.0144     CD =  0.00552   =>   CDf =  0.00402    CDp =  0.00149
#
#  Side 1  free  transition at x/c =  0.5497   53
#  Side 2  free  transition at x/c =  0.9401   75
#
#    4   rms: 0.1236E-04   max: -.1521E-03   D at   75  2
#        a =  1.250      CL =  0.3020
#       Cm = -0.0144     CD =  0.00552   =>   CDf =  0.00403    CDp =  0.00149
#       9.000    4.2731   0.005516   0.001432   0.001520   0.000088    0.5497     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5497   53
#  Side 2  free  transition at x/c =  0.9401   75
#
#    1   rms: 0.4623E-01   max: 0.1670E+00   D at   76  2
#        a =  1.500      CL =  0.3353
#       Cm = -0.0155     CD =  0.00556   =>   CDf =  0.00403    CDp =  0.00154
#
#  Side 1  free  transition at x/c =  0.5421   53
#  Side 2  free  transition at x/c =  0.9466   75
#
#    2   rms: 0.8099E-02   max: -.7508E-01   C at   75  2
#        a =  1.500      CL =  0.3314
#       Cm = -0.0146     CD =  0.00558   =>   CDf =  0.00406    CDp =  0.00153
#
#  Side 1  free  transition at x/c =  0.5431   53
#  Side 2  free  transition at x/c =  0.9500   75
#
#    3   rms: 0.8643E-03   max: -.5496E-02   C at   75  2
#        a =  1.500      CL =  0.3323
#       Cm = -0.0148     CD =  0.00558   =>   CDf =  0.00404    CDp =  0.00154
#
#  Side 1  free  transition at x/c =  0.5431   53
#  Side 2  free  transition at x/c =  0.9497   75
#
#    4   rms: 0.1811E-04   max: -.1678E-03   C at   75  2
#        a =  1.500      CL =  0.3323
#       Cm = -0.0148     CD =  0.00558   =>   CDf =  0.00404    CDp =  0.00154
#       9.000    4.2548   0.005584   0.001446   0.001529   0.000084    0.5431     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5431   53
#  Side 2  free  transition at x/c =  0.9497   75
#
#    1   rms: 0.4080E-01   max: -.1392E+00   T at   75  2
#        a =  1.750      CL =  0.3577
#       Cm = -0.0142     CD =  0.00566   =>   CDf =  0.00404    CDp =  0.00162
#
#  Side 1  free  transition at x/c =  0.5366   52
#  Side 2  free  transition at x/c =  0.9618   76
#
#    2   rms: 0.2161E-01   max: 0.2568E+00   C at   76  2
#        a =  1.750      CL =  0.3634
#       Cm = -0.0155     CD =  0.00566   =>   CDf =  0.00408    CDp =  0.00158
#
#  Side 1  free  transition at x/c =  0.5366   52
#  Side 2  free  transition at x/c =  0.9569   76
#
#    3   rms: 0.2284E-02   max: -.1898E-01   D at   78  2
#        a =  1.750      CL =  0.3651
#       Cm = -0.0159     CD =  0.00569   =>   CDf =  0.00408    CDp =  0.00160
#
#  Side 1  free  transition at x/c =  0.5365   52
#  Side 2  free  transition at x/c =  0.9561   76
#
#    4   rms: 0.1483E-03   max: -.1401E-02   C at   76  2
#        a =  1.750      CL =  0.3650
#       Cm = -0.0158     CD =  0.00569   =>   CDf =  0.00408    CDp =  0.00160
#
#  Side 1  free  transition at x/c =  0.5365   52
#  Side 2  free  transition at x/c =  0.9561   76
#
#    5   rms: 0.2621E-06   max: -.2884E-05   C at  102  2
#        a =  1.750      CL =  0.3650
#       Cm = -0.0158     CD =  0.00569   =>   CDf =  0.00408    CDp =  0.00160
#       9.000    4.2214   0.005686   0.001462   0.001537   0.000076    0.5365     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5365   52
#  Side 2  free  transition at x/c =  0.9561   76
#
#    1   rms: 0.4631E-01   max: 0.1348E+00   D at   77  2
#        a =  2.000      CL =  0.4001
#       Cm = -0.0173     CD =  0.00574   =>   CDf =  0.00408    CDp =  0.00166
#
#  Side 1  free  transition at x/c =  0.5288   53
#  Side 2  free  transition at x/c =  0.9604   75
#
#    2   rms: 0.9814E-02   max: 0.1074E+00   D at    3  1
#        a =  2.000      CL =  0.3980
#       Cm = -0.0169     CD =  0.00576   =>   CDf =  0.00410    CDp =  0.00166
#
#  Side 1  free  transition at x/c =  0.5297   53
#  Side 2  free  transition at x/c =  0.9619   75
#
#    3   rms: 0.5637E-03   max: 0.5615E-02   D at    4  1
#        a =  2.000      CL =  0.3981
#       Cm = -0.0169     CD =  0.00576   =>   CDf =  0.00409    CDp =  0.00167
#
#  Side 1  free  transition at x/c =  0.5297   53
#  Side 2  free  transition at x/c =  0.9619   75
#
#    4   rms: 0.4498E-06   max: -.4077E-05   D at    8  1
#        a =  2.000      CL =  0.3981
#       Cm = -0.0169     CD =  0.00576   =>   CDf =  0.00409    CDp =  0.00167
#       9.000    4.2178   0.005762   0.001476   0.001554   0.000078    0.5297     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1  free  transition at x/c =  0.5297   53
#  Side 2  free  transition at x/c =  0.9619   75
#
#    1   rms: 0.4383E-01   max: -.1019E+00   T at   75  2
#        a =  2.250      CL =  0.4291
#       Cm = -0.0175     CD =  0.00585   =>   CDf =  0.00409    CDp =  0.00176
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9675   76
#
#    2   rms: 0.1879E-02   max: 0.2128E-01   D at   53  1
#        a =  2.250      CL =  0.4286
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00415    CDp =  0.00173
#
#  Side 1  free  transition at x/c =  0.5220   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#    3   rms: 0.5070E-02   max: -.9770E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#    4   rms: 0.4950E-02   max: -.9577E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#    5   rms: 0.4961E-02   max: -.9596E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#    6   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#    7   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#    8   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#    9   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   10   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   11   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   12   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   13   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   14   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   15   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   16   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   17   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   18   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   19   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   20   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   21   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   22   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   23   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   24   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   25   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   26   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   27   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   28   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   29   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   30   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   31   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   32   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   33   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   34   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   35   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   36   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   37   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   38   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   39   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   40   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   41   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   42   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   43   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   44   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   45   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   46   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   47   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   48   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   49   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   50   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   51   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   52   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   53   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   54   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   55   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   56   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   57   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   58   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   59   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   60   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   61   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   62   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   63   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   64   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   65   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   66   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   67   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   68   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   69   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   70   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   71   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   72   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   73   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   74   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   75   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   76   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   77   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   78   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   79   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   80   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   81   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   82   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   83   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   84   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   85   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   86   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   87   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   88   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   89   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   90   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   91   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   92   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   93   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   94   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   95   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   96   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   97   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   98   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#   99   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#  100   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#  101   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#  102   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#  103   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#  104   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#  105   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#  106   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
#       Cm = -0.0174     CD =  0.00588   =>   CDf =  0.00416    CDp =  0.00172
#
#  Side 1  free  transition at x/c =  0.5221   52
#  Side 2  free  transition at x/c =  0.9679   76
#
#  107   rms: 0.4960E-02   max: -.9595E-01   C at   52  1
#        a =  2.250      CL =  0.4285
# ...
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  189   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  190   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  191   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  192   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  193   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  194   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  195   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  196   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  197   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  198   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  199   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  200   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  201   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  202   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  203   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  204   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#  205   rms: 0.1505E-01   max: 0.6279E-01   T at   24  2
#        a =-28.750      CL = -0.7206
#       Cm =  0.1176     CD =  0.34428   =>   CDf =  0.00117    CDp =  0.34311
#  VISCAL:  Convergence failed
#       9.000    2.7908   0.344283   0.000000   0.000000   0.000000    1.0000     #
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1871E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    1   rms: 0.2251E-01   max: -.1683E+00   C at   66  1   RLX: 0.202
#        a =-29.000      CL = -0.7174
#       Cm =  0.1171     CD =  0.33637   =>   CDf =  0.00117    CDp =  0.33520
#
#  MRCHDU: Convergence failed at  23  side 2    Res =  0.1261E-02
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    2   rms: 0.1826E-01   max: -.1643E+00   C at   66  1
#        a =-29.000      CL = -0.7249
#       Cm =  0.1196     CD =  0.34973   =>   CDf =  0.00117    CDp =  0.34856
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    3   rms: 0.7655E-02   max: -.7808E-01   C at   66  1
#        a =-29.000      CL = -0.7237
#       Cm =  0.1195     CD =  0.34582   =>   CDf =  0.00117    CDp =  0.34466
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    4   rms: 0.3167E-02   max: -.6152E-01   C at   66  1
#        a =-29.000      CL = -0.7230
#       Cm =  0.1195     CD =  0.34340   =>   CDf =  0.00117    CDp =  0.34223
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    5   rms: 0.7143E-03   max: -.1660E-01   C at   66  1
#        a =-29.000      CL = -0.7228
#       Cm =  0.1195     CD =  0.34288   =>   CDf =  0.00116    CDp =  0.34171
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    6   rms: 0.5589E-04   max: -.1360E-02   C at   66  1
#        a =-29.000      CL = -0.7228
#       Cm =  0.1195     CD =  0.34285   =>   CDf =  0.00116    CDp =  0.34169
#       9.000    2.8225   0.342852   0.000000   0.000000   0.000000    1.0000     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    1   rms: 0.1740E-01   max: -.1799E+00   C at   66  1   RLX: 0.200
#        a =-29.250      CL = -0.7223
#       Cm =  0.1199     CD =  0.34422   =>   CDf =  0.00116    CDp =  0.34305
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    2   rms: 0.1415E-01   max: -.1515E+00   C at   66  1
#        a =-29.250      CL = -0.7276
#       Cm =  0.1215     CD =  0.34934   =>   CDf =  0.00116    CDp =  0.34818
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    3   rms: 0.3260E-02   max: -.2989E-01   C at   66  1
#        a =-29.250      CL = -0.7271
#       Cm =  0.1214     CD =  0.34790   =>   CDf =  0.00116    CDp =  0.34675
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    4   rms: 0.1220E-02   max: -.2264E-01   C at   66  1
#        a =-29.250      CL = -0.7269
#       Cm =  0.1214     CD =  0.34708   =>   CDf =  0.00116    CDp =  0.34592
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    5   rms: 0.3509E-03   max: -.7940E-02   C at   66  1
#        a =-29.250      CL = -0.7268
#       Cm =  0.1214     CD =  0.34683   =>   CDf =  0.00116    CDp =  0.34567
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    6   rms: 0.4614E-04   max: -.9206E-03   C at   66  1
#        a =-29.250      CL = -0.7268
#       Cm =  0.1214     CD =  0.34681   =>   CDf =  0.00116    CDp =  0.34565
#       9.000    2.8410   0.346810   0.000000   0.000000   0.000000    1.0000     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    1   rms: 0.1812E-01   max: -.1869E+00   C at   66  1   RLX: 0.198
#        a =-29.500      CL = -0.7262
#       Cm =  0.1218     CD =  0.34815   =>   CDf =  0.00116    CDp =  0.34699
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    2   rms: 0.1484E-01   max: -.1575E+00   C at   66  1
#        a =-29.500      CL = -0.7315
#       Cm =  0.1234     CD =  0.35329   =>   CDf =  0.00116    CDp =  0.35213
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    3   rms: 0.3251E-02   max: -.3179E-01   C at   66  1
#        a =-29.500      CL = -0.7310
#       Cm =  0.1234     CD =  0.35182   =>   CDf =  0.00115    CDp =  0.35067
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    4   rms: 0.1186E-02   max: -.2278E-01   C at   66  1
#        a =-29.500      CL = -0.7308
#       Cm =  0.1234     CD =  0.35104   =>   CDf =  0.00115    CDp =  0.34989
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    5   rms: 0.3449E-03   max: -.7928E-02   C at   66  1
#        a =-29.500      CL = -0.7307
#       Cm =  0.1233     CD =  0.35080   =>   CDf =  0.00115    CDp =  0.34965
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    6   rms: 0.4230E-04   max: -.1038E-02   C at   66  1
#        a =-29.500      CL = -0.7307
#       Cm =  0.1233     CD =  0.35078   =>   CDf =  0.00115    CDp =  0.34963
#       9.000    2.8596   0.350783   0.000000   0.000000   0.000000    1.0000     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    1   rms: 0.1931E-01   max: -.1920E+00   C at   66  1   RLX: 0.197
#        a =-29.750      CL = -0.7301
#       Cm =  0.1237     CD =  0.35212   =>   CDf =  0.00115    CDp =  0.35097
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    2   rms: 0.1589E-01   max: -.1621E+00   C at   66  1
#        a =-29.750      CL = -0.7354
#       Cm =  0.1253     CD =  0.35729   =>   CDf =  0.00115    CDp =  0.35614
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    3   rms: 0.3440E-02   max: -.3417E-01   C at   66  1
#        a =-29.750      CL = -0.7349
#       Cm =  0.1253     CD =  0.35584   =>   CDf =  0.00114    CDp =  0.35470
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    4   rms: 0.1217E-02   max: -.2364E-01   C at   66  1
#        a =-29.750      CL = -0.7347
#       Cm =  0.1253     CD =  0.35507   =>   CDf =  0.00114    CDp =  0.35393
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    5   rms: 0.3833E-03   max: -.8923E-02   C at   66  1
#        a =-29.750      CL = -0.7346
#       Cm =  0.1253     CD =  0.35481   =>   CDf =  0.00114    CDp =  0.35367
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    6   rms: 0.5024E-04   max: -.1284E-02   C at   66  1
#        a =-29.750      CL = -0.7346
#       Cm =  0.1253     CD =  0.35479   =>   CDf =  0.00114    CDp =  0.35365
#       9.000    2.8784   0.354793   0.000000   0.000000   0.000000    1.0000     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#  Calculating wake trajectory ...
#  Calculating source influence matrix ...
#
#  Solving BL system ...
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    1   rms: 0.2090E-01   max: -.1975E+00   C at   66  1   RLX: 0.195
#        a =-30.000      CL = -0.7340
#       Cm =  0.1256     CD =  0.35613   =>   CDf =  0.00114    CDp =  0.35499
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0038   23
#
#    2   rms: 0.1710E-01   max: -.1673E+00   C at   66  1
#        a =-30.000      CL = -0.7393
#       Cm =  0.1272     CD =  0.36132   =>   CDf =  0.00114    CDp =  0.36018
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0037   23
#
#    3   rms: 0.4089E-02   max: -.3478E-01   C at   66  1
#        a =-30.000      CL = -0.7389
#       Cm =  0.1271     CD =  0.35994   =>   CDf =  0.00113    CDp =  0.35881
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0037   23
#
#    4   rms: 0.1330E-02   max: -.2513E-01   C at   66  1
#        a =-30.000      CL = -0.7386
#       Cm =  0.1271     CD =  0.35916   =>   CDf =  0.00113    CDp =  0.35802
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0037   23
#
#    5   rms: 0.4841E-03   max: -.1144E-01   C at   66  1
#        a =-30.000      CL = -0.7385
#       Cm =  0.1271     CD =  0.35884   =>   CDf =  0.00113    CDp =  0.35771
#
#  Side 1 forced transition at x/c =  1.0000   66
#  Side 2  free  transition at x/c =  0.0037   23
#
#    6   rms: 0.6025E-04   max: -.1564E-02   C at   66  1
#        a =-30.000      CL = -0.7385
#       Cm =  0.1271     CD =  0.35882   =>   CDf =  0.00113    CDp =  0.35769
#       9.000    2.8975   0.358823   0.000000   0.000000   0.000000    1.0000     #
#
#  Point added to stored polar  1
#  Save file unspecified or not available
#  Dump file unspecified or not available
#
# .OPERva   c>
#         airfoil                    Re           Mach       NcritT  NcritB  XtripT  XtripB       file
#        ------------------------  ------------  ----------  ------  ------  ------  ------    -------------------
#  >  1  airfoil                   1.000e6       0.000         9.00    9.00   1.000   1.000
#
# Enter polar output filename   s>
# .OPERva   c>
#  XFOIL   c>
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG

# %%
import time
from ada.geometry.airfoils.kulfan import units
afl = Kulfan()
afl.naca4('2412')
afl.chord = 1.0*units.m
t0 = time.time()
Ixx1 = afl.Ixx
t1 = time.time()
afl.utility.Npoints = 20
Ixx2 = afl.Ixx
t2 = time.time()
print(Ixx1)
print(Ixx2)
print((Ixx1 - Ixx2)/Ixx1)
print(t1-t0)
print(t2-t1)
# Out:
# 6.838253381218481e-05 meter ** 4
# 6.789750498758429e-05 meter ** 4
# 0.007092875878695464 dimensionless
# 2.9528698921203613
# 0.12273406982421875

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
uc = [0.2610193078567949, 0.5267922969808392, 0.24757697190183187, 0.2041020748577004, ]
lc = [-0.16783842020330567, -0.19193184472640137, -0.1843528586643609, 0.22241717079511478]
afl = Kulfan()
afl.upperCoefficients = uc
afl.lowerCoefficients = lc
plt.plot(afl.xcoordinates, afl.ycoordinates)
plt.axis('equal')
afl.write2file('test.dat')

hts = afl.getNormalizedHeight()
print(hts)
if any(hts<0):
    print('fail')
# Out:
# [0.         0.00481216 0.00962787 0.01445047 0.01928323 0.0241292
#  0.02899125 0.03387192 0.03877346 0.0436977  0.04864608 0.05361952
#  0.05861846 0.06364275 0.06869167 0.07376388 0.07885737 0.08396948
#  0.08909684 0.0942354  0.09938036 0.10452624 0.10966681 0.11479517
#  0.11990368 0.12498404 0.13002727 0.13502377 0.13996333 0.14483515
#  0.14962792 0.15432983 0.15892865 0.16341175 0.16776617 0.1719787
#  0.17603589 0.1799242  0.18363    0.18713965 0.1904396  0.19351648
#  0.1963571  0.19894863 0.20127859 0.203335   0.2051064  0.20658196
#  0.20775156 0.20860585 0.20913635 0.20933547 0.20919664 0.20871434
#  0.20788418 0.20670295 0.20516867 0.20328067 0.20103961 0.19844752
#  0.19550786 0.19222554 0.18860694 0.18465995 0.18039397 0.1758199
#  0.1709502  0.16579882 0.16038125 0.15471446 0.14881689 0.14270845
#  0.13641043 0.12994551 0.1233377  0.11661227 0.10979572 0.10291567
#  0.09600085 0.089081   0.08218676 0.07534965 0.06860193 0.06197653
#  0.05550695 0.04922717 0.04317154 0.03737468 0.03187138 0.02669648
#  0.02188478 0.01747092 0.01348926 0.0099738  0.00695805 0.0044749
#  0.00255658 0.00123449 0.00053914 0.0005    ]

# %%
import tempfile
import os

tempDatfile    = tempfile.NamedTemporaryFile(mode = 'w', delete=True)
if os.path.exists(tempDatfile.name):
    os.remove(tempDatfile.name)
print(tempDatfile.name)
# Out:
# /tmp/tmpg6gow94x

# %%
import time
datestr = time.strftime("%Y_%b_%d_%H-%M", time.localtime())
print(datestr)

print('hello world')
# Out:
# 2025_Apr_01_14-11
# hello world
